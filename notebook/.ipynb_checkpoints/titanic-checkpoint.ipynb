# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import re

# %%
df = pd.read_csv("../data/train.csv")
df2 = pd.read_csv("../data/test.csv")

# %%
df.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
plt.figure(figsize=(17,13))
ax = sns.heatmap(df.isna(),cbar=False);
ax.set_yticks([]);
ax.set_title('Missing Data');

# %%
plt.figure(figsize=(17,13))
ax2 = sns.heatmap(df2.isna(),cbar=False);
ax2.set_yticks([]);
ax2.set_title('Missing Data');

# %%
df[df['Embarked'].isna()]
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 61            62         1       1                        Icard, Miss. Amelie
# 829          830         1       1  Stone, Mrs. George Nelson (Martha Evelyn)
#
#         Sex   Age  SibSp  Parch  Ticket  Fare Cabin Embarked
# 61   female  38.0      0      0  113572  80.0   B28      NaN
# 829  female  62.0      0      0  113572  80.0   B28      NaN

# %%
df['Embarked'].value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
df['Embarked'].mode()[0]
# Out:
# 'S'

# %%
# Fills with mode where 'Embarked' equals NaN

df['Embarked'].fillna(df.Embarked.mode()[0], inplace=True)

# %%
df.Fare.describe()
# Out:
# count    891.000000
# mean      32.204208
# std       49.693429
# min        0.000000
# 25%        7.910400
# 50%       14.454200
# 75%       31.000000
# max      512.329200
# Name: Fare, dtype: float64

# %%
df.Fare.mode()
# Out:
# 0    8.05
# dtype: float64

# %%
classes = df.Pclass.unique()

# %%
classes.sort()
classes
# Out:
# array([1, 2, 3], dtype=int64)

# %%
class_fare = pd.DataFrame()
for clas in classes:
    class_fare[clas] = df[df.Pclass == clas].Fare.describe()
class_fare = class_fare.T
class_fare
# Out:
#    count       mean        std  min       25%      50%   75%       max
# 1  216.0  84.154687  78.380373  0.0  30.92395  60.2875  93.5  512.3292
# 2  184.0  20.662183  13.417399  0.0  13.00000  14.2500  26.0   73.5000
# 3  491.0  13.675550  11.778142  0.0   7.75000   8.0500  15.5   69.5500

# %%
def fare_mean(x):
    return class_fare.loc[x, 'mean']

# %%
df['Class_Fare'] = df['Pclass'].apply(fare_mean)

# %%
df['Fare']
# Out:
# 0       7.2500
# 1      71.2833
# 2       7.9250
# 3      53.1000
# 4       8.0500
#         ...
# 886    13.0000
# 887    30.0000
# 888    23.4500
# 889    30.0000
# 890     7.7500
# Name: Fare, Length: 891, dtype: float64

# %%
df['Fare'].fillna(df['Class_Fare'])
# Out:
# 0       7.2500
# 1      71.2833
# 2       7.9250
# 3      53.1000
# 4       8.0500
#         ...
# 886    13.0000
# 887    30.0000
# 888    23.4500
# 889    30.0000
# 890     7.7500
# Name: Fare, Length: 891, dtype: float64

# %%
df.loc[152]
# Out:
# PassengerId                 153
# Survived                      0
# Pclass                        3
# Name           Meo, Mr. Alfonzo
# Sex                        male
# Age                        55.5
# SibSp                         0
# Parch                         0
# Ticket               A.5. 11206
# Fare                       8.05
# Cabin                       NaN
# Embarked                      S
# Class_Fare              13.6756
# Name: 152, dtype: object

# %%
titulo = re.compile(r'\b[a-zA-Z]+\b\.')
def title(full_name):
    x = re.search(titulo, full_name)
    return x.group()

# %%
def correct_name(full_name):
    if '(' in full_name:
        x = re.search(r'(?<=[\(])(?P<nome>[\W\w]+)(?=[\)])', full_name)
        #x = re.search(r'(?<=[\(])(?P<nome>[\"\.\-\w\s]+)(?=[\)])', full_name)
        return x.group('nome')
    else:
        surname = re.search(r'^(?P<sobrenome>[\W\w]+)(?=[\,])', full_name)
        name = re.search(r'(?:\b[a-zA-Z]+\b\.\s)(?P<nome>[^\(][\w\W]+)', full_name)
        #surname = re.search(r'^(?P<sobrenome>[\'\-\w\s]+)(?=[\,])', full_name)
        #name = re.search(r'(?:\b[a-zA-Z]+\b\.\s)(?P<nome>[\w\s\"]+)', full_name)
        return name.group('nome') + ' ' + surname.group('sobrenome')

# %%
df['Title'] = df['Name'].apply(title)

# %%
df['Person'] = df['Name'].apply(correct_name)

# %%
df2['Name'].apply(correct_name).sample(20)
# Out:
# 365                       Annie Bullen
# 325                          Ali Assam
# 208             Edith Louise Rosenbaum
# 132                            Frances
# 417                    Michael J Peter
# 149                   William Lahtinen
# 261           August Ferdinand Nilsson
# 230             George Frederick Sweet
# 388                    Patrick Canavan
# 397        Margaretha Emerentia Stehli
# 21                    Artur Karl Olsen
# 71                       Lazar Minkoff
# 389                 Paul Folke Palsson
# 25                  Alexander A Robins
# 99             William Henry Nancarrow
# 125                  Laura Alice Cribb
# 373                  William H Harbeck
# 306    Hudson Joshua Creighton Allison
# 148               John Bertram Crafton
# 181        Alexander Taylor Jr Compton
# Name: Name, dtype: object

# %%
df['Title'].unique()
# Out:
# array(['Mr.', 'Mrs.', 'Miss.', 'Master.', 'Don.', 'Rev.', 'Dr.', 'Mme.',
#        'Ms.', 'Major.', 'Lady.', 'Sir.', 'Mlle.', 'Col.', 'Capt.',
#        'Countess.', 'Jonkheer.'], dtype=object)

# %%
df[df['Title'].str.contains('Rev.')]
# Out:
#      PassengerId  Survived  Pclass                               Name   Sex  \
# 149          150         0       2  Byles, Rev. Thomas Roussel Davids  male
# 150          151         0       2         Bateman, Rev. Robert James  male
# 249          250         0       2      Carter, Rev. Ernest Courtenay  male
# 626          627         0       2     Kirkland, Rev. Charles Leonard  male
# 848          849         0       2                  Harper, Rev. John  male
# 886          887         0       2              Montvila, Rev. Juozas  male
#
#       Age  SibSp  Parch       Ticket    Fare Cabin Embarked  Class_Fare Title  \
# 149  42.0      0      0       244310  13.000   NaN        S   20.662183  Rev.
# 150  51.0      0      0  S.O.P. 1166  12.525   NaN        S   20.662183  Rev.
# 249  54.0      1      0       244252  26.000   NaN        S   20.662183  Rev.
# 626  57.0      0      0       219533  12.350   NaN        Q   20.662183  Rev.
# 848  28.0      0      1       248727  33.000   NaN        S   20.662183  Rev.
# 886  27.0      0      0       211536  13.000   NaN        S   20.662183  Rev.
#
#                           Person
# 149  Thomas Roussel Davids Byles
# 150         Robert James Bateman
# 249      Ernest Courtenay Carter
# 626     Charles Leonard Kirkland
# 848                  John Harper
# 886              Juozas Montvila

# %%
df[df.Embarked.isna()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked, Class_Fare, Title, Person]
# Index: []

# %%
def family(fname):
    return df[df['Name'].str.contains(fname)].values, df2[df2['Name'].str.contains(fname)].values

# %%
family('Stone')
# Out:
# (array([[320, 1, 1,
#          'Spedden, Mrs. Frederic Oakley (Margaretta Corning Stone)',
#          'female', 40.0, 1, 1, '16966', 134.5, 'E34', 'C',
#          84.15468749999992, 'Mrs.', 'Margaretta Corning Stone'],
#         [830, 1, 1, 'Stone, Mrs. George Nelson (Martha Evelyn)', 'female',
#          62.0, 0, 0, '113572', 80.0, 'B28', 'S', 84.15468749999992,
#          'Mrs.', 'Martha Evelyn']], dtype=object),
#  array([], shape=(0, 11), dtype=object))

# %%
df.info() # Método .info
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       891 non-null object
# Class_Fare     891 non-null float64
# Title          891 non-null object
# Person         891 non-null object
# dtypes: float64(3), int64(5), object(7)
# memory usage: 104.5+ KB

# %%
df.T.head()
# Out:
#                                  0    \
# PassengerId                        1
# Survived                           0
# Pclass                             3
# Name         Braund, Mr. Owen Harris
# Sex                             male
#
#                                                            1    \
# PassengerId                                                  2
# Survived                                                     1
# Pclass                                                       1
# Name         Cumings, Mrs. John Bradley (Florence Briggs Th...
# Sex                                                     female
#
#                                 2    \
# PassengerId                       3
# Survived                          1
# Pclass                            3
# Name         Heikkinen, Miss. Laina
# Sex                          female
#
#                                                       3    \
# PassengerId                                             4
# Survived                                                1
# Pclass                                                  1
# Name         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# Sex                                                female
#
#                                   4                 5    \
# PassengerId                         5                 6
# Survived                            0                 0
# Pclass                              3                 3
# Name         Allen, Mr. William Henry  Moran, Mr. James
# Sex                              male              male
#
#                                  6                               7    \
# PassengerId                        7                               8
# Survived                           0                               0
# Pclass                             1                               3
# Name         McCarthy, Mr. Timothy J  Palsson, Master. Gosta Leonard
# Sex                             male                            male
#
#                                                            8    \
# PassengerId                                                  9
# Survived                                                     1
# Pclass                                                       3
# Name         Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# Sex                                                     female
#
#                                              9    ...                 881  \
# PassengerId                                   10  ...                 882
# Survived                                       1  ...                   0
# Pclass                                         2  ...                   3
# Name         Nasser, Mrs. Nicholas (Adele Achem)  ...  Markun, Mr. Johann
# Sex                                       female  ...                male
#
#                                       882                            883  \
# PassengerId                           883                            884
# Survived                                0                              0
# Pclass                                  3                              2
# Name         Dahlberg, Miss. Gerda Ulrika  Banfield, Mr. Frederick James
# Sex                                female                           male
#
#                                 884                                   885  \
# PassengerId                     885                                   886
# Survived                          0                                     0
# Pclass                            3                                     3
# Name         Sutehall, Mr. Henry Jr  Rice, Mrs. William (Margaret Norton)
# Sex                            male                                female
#
#                                886                           887  \
# PassengerId                    887                           888
# Survived                         0                             1
# Pclass                           2                             1
# Name         Montvila, Rev. Juozas  Graham, Miss. Margaret Edith
# Sex                           male                        female
#
#                                                   888                    889  \
# PassengerId                                       889                    890
# Survived                                            0                      1
# Pclass                                              3                      1
# Name         Johnston, Miss. Catherine Helen "Carrie"  Behr, Mr. Karl Howell
# Sex                                            female                   male
#
#                              890
# PassengerId                  891
# Survived                       0
# Pclass                         3
# Name         Dooley, Mr. Patrick
# Sex                         male
#
# [5 rows x 891 columns]

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# Class_Fare     float64
# Title           object
# Person          object
# dtype: object

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked', 'Class_Fare', 'Title',
#        'Person'],
#       dtype='object')

# %%
df['Pclass']
# Out:
# 0      3
# 1      1
# 2      3
# 3      1
# 4      3
#       ..
# 886    2
# 887    1
# 888    3
# 889    1
# 890    3
# Name: Pclass, Length: 891, dtype: int64

# %%
males_survived = df[(df["Sex"] == "male") & (df["Survived"] == 1)]

# %%
df.Survived.value_counts(normalize=True)
# Out:
# 0    0.616162
# 1    0.383838
# Name: Survived, dtype: float64

# %%
type(df.Survived)
# Out:
# pandas.core.series.Series

# %%
type(df['Survived'])
# Out:
# pandas.core.series.Series

# %%
df['Survived'].value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
df2 = pd.read_csv("../data/test.csv")
